# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
# !pip install cartopy
# !pip install geoviews
# !pip install pyproj

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Requirement already satisfied: cartopy in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy) (3.7.2)
# Requirement already satisfied: shapely>=1.7 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy) (23.1)
# Requirement already satisfied: pyshp>=2.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from pyproj>=3.1.0->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Requirement already satisfied: geoviews in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (1.11.0)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (3.2.1)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.17.1)
# Requirement already satisfied: packaging in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (23.1)
# Requirement already satisfied: numpy in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.24.3)
# Requirement already satisfied: shapely in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (2.0.2)
# Requirement already satisfied: param in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.2.3)
# Requirement already satisfied: pyproj in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.3.2)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: markdown in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: certifi in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from pyproj->geoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.16)
# Requirement already satisfied: pyproj in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (3.6.1)
# Requirement already satisfied: certifi in c:\users\iec08\anaconda3\envs\dev\lib\site-packages (from pyproj) (2023.7.22)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0            cody  44.5263 -109.0565     52.92        37          20
# 1        1          nemuro  43.3236  145.5750     34.74        71           4
# 2        2  puerto natales -51.7236  -72.4875     48.65        40          75
# 3        3        hermanus -34.4187   19.2345     60.30        85          33
# 4        4   blackmans bay -43.0167  147.3167     47.52        76         100
#
#    Wind Speed Country        Date
# 0       19.57      US  1699731671
# 1       13.02      JP  1699731673
# 2       18.41      CL  1699731674
# 3       10.42      ZA  1699731399
# 4        1.01      AU  1699731668

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points("Lng",
                                     "Lat",
                                     geo=True,
                                     tiles = "OSM",
                                     frame_width=700,
                                     frame_height=500,
                                     c="City",
                                     size="Humidity")

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df=city_data_df.loc[(city_data_df['Max Temp'] < 27) & (city_data_df['Max Temp'] > 21)]
city_data_df=city_data_df.loc[city_data_df['Wind Speed'] < 4.5]
city_data_df=city_data_df.loc[city_data_df['Cloudiness'] == 0]

# Drop any rows with null values
city_data_df = city_data_df.dropna()

# Display sample data
city_data_df
# Out:
#      City_ID      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 497      497  akureyri  65.6835 -18.0878     22.93        86           0
#
#      Wind Speed Country        Date
# 497         2.3      IS  1699731715

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
city = city_data_df["City"]
country = city_data_df["Country"]
lat = city_data_df["Lat"]
lng = city_data_df["Lng"]
humidity = city_data_df["Humidity"]

hotel_df = pd.DataFrame({"City":city, 
             "Country":country, 
              "Latitude":lat, 
              "Longitude":lng, 
              "Humidity":humidity,
                "Hotel Nane": ""})

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API


# Display sample data
hotel_df
# Out:
#          City Country  Latitude  Longitude  Humidity Hotel Nane
# 497  akureyri      IS   65.6835   -18.0878        86

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Latitude"]
    longitude = row["Longitude"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# akureyri - nearest hotel: Hótel Norðurland
#          City Country  Latitude  Longitude  Humidity Hotel Nane  \
# 497  akureyri      IS   65.6835   -18.0878        86
#
#            Hotel Name
# 497  Hótel Norðurland

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75,
    hover_cols=["Hotel Name", "Country"])

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)
